# %% [markdown]
# # Autoencoder — AE v5
#
# **Input:** `nominal_scaled`, `kategori_detail_encoded_scaled`, `hour_sin_scaled`, `hour_cos_scaled`, `nominal_z_user_kat_scaled`

# %%
import os
import joblib
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix

tf.random.set_seed(42)
np.random.seed(42)

DATA_DIR  = '../../../data/new'
MODEL_DIR = '../../../model/03_ae'
os.makedirs(MODEL_DIR, exist_ok=True)

print(f"TensorFlow : {tf.__version__}")
print(tf.config.list_physical_devices())
# Out:
# TensorFlow : 2.21.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %% [markdown]
# ## Load Data

# %%
meta = joblib.load(f'{MODEL_DIR}/preprocessing_meta.pkl')
SCALED_COLS = meta['scaled_cols']

df_train     = pd.read_csv(f'{DATA_DIR}/pre_train.csv')
df_threshold = pd.read_csv(f'{DATA_DIR}/pre_threshold.csv', parse_dates=['timestamp'])

X_train = df_train[SCALED_COLS].values.astype(np.float32)
INPUT_DIM = X_train.shape[1]

print(f"X_train   : {X_train.shape}")
print(f"threshold : {df_threshold.shape}")
print(f"Input dim : {INPUT_DIM}")
# Out:
# X_train   : (176459, 5)
# threshold : (45110, 17)
# Input dim : 5

# %% [markdown]
# ## Arsitektur
#
# ```
# Input(5) → Dense(16) → Dense(8) → Dense(2) [bottleneck]
#          → Dense(8)  → Dense(16) → Dense(5)
# ```
#
# **Loss: MAE**

# %%
def build_autoencoder(input_dim):
    inp     = Input(shape=(input_dim,))
    x       = Dense(32, activation='relu')(inp)
    x       = Dense(16,  activation='relu')(x)
    encoded = Dense(4,  activation='relu')(x)
    x       = Dense(16,  activation='relu')(encoded)
    x       = Dense(32, activation='relu')(x)
    out     = Dense(input_dim, activation='linear')(x)
    model   = Model(inputs=inp, outputs=out)
    model.compile(optimizer=tf.keras.optimizers.Adam(1e-3), loss='mae')
    return model

autoencoder = build_autoencoder(INPUT_DIM)
autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 5)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │           192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │            68 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 16)             │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 5)              │           165 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,577 (6.16 KB)
#  Trainable params: 1,577 (6.16 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Training

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,    
        min_lr=1e-4,     
        verbose=1
    ),
    ModelCheckpoint(f'{MODEL_DIR}/autoencoder.keras', monitor='val_loss', save_best_only=True, verbose=0),
]

history = autoencoder.fit(
    X_train, X_train,
    epochs=150,
    batch_size=256,
    validation_split=0.1,
    shuffle=True,
    callbacks=callbacks,
    verbose=1,
)

print(f"Best val_loss : {min(history.history['val_loss']):.6f}")
# Out:
# Epoch 1/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 1s 548us/step - loss: 0.2307 - val_loss: 0.0835 - learning_rate: 0.0010
# Epoch 2/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 0.0780 - val_loss: 0.0684 - learning_rate: 0.0010
# Epoch 3/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 0.0704 - val_loss: 0.0675 - learning_rate: 0.0010
# Epoch 4/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step - loss: 0.0668 - val_loss: 0.0644 - learning_rate: 0.0010
# Epoch 5/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step - loss: 0.0638 - val_loss: 0.0602 - learning_rate: 0.0010
# Epoch 6/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step - loss: 0.0608 - val_loss: 0.0532 - learning_rate: 0.0010
# Epoch 7/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 447us/step - loss: 0.0564 - val_loss: 0.0503 - learning_rate: 0.0010
# Epoch 8/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step - loss: 0.0536 - val_loss: 0.0485 - learning_rate: 0.0010
# Epoch 9/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - loss: 0.0513 - val_loss: 0.0483 - learning_rate: 0.0010
# Epoch 10/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - loss: 0.0506 - val_loss: 0.0522 - learning_rate: 0.0010
# Epoch 11/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step - loss: 0.0500 - val_loss: 0.0465 - learning_rate: 0.0010
# Epoch 12/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step - loss: 0.0487 - val_loss: 0.0490 - learning_rate: 0.0010
# Epoch 13/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step - loss: 0.0488 - val_loss: 0.0495 - learning_rate: 0.0010
# Epoch 14/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 0.0486 - val_loss: 0.0452 - learning_rate: 0.0010
# Epoch 15/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 0.0482 - val_loss: 0.0480 - learning_rate: 0.0010
# Epoch 16/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 0.0486 - val_loss: 0.0457 - learning_rate: 0.0010
# Epoch 17/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 0.0476 - val_loss: 0.0513 - learning_rate: 0.0010
# Epoch 18/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - loss: 0.0479 - val_loss: 0.0449 - learning_rate: 0.0010
# Epoch 19/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 0.0467 - val_loss: 0.0473 - learning_rate: 0.0010
# Epoch 20/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - loss: 0.0465 - val_loss: 0.0451 - learning_rate: 0.0010
# Epoch 21/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 447us/step - loss: 0.0461 - val_loss: 0.0444 - learning_rate: 0.0010
# Epoch 22/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 434us/step - loss: 0.0465 - val_loss: 0.0418 - learning_rate: 0.0010
# Epoch 23/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - loss: 0.0454 - val_loss: 0.0445 - learning_rate: 0.0010
# Epoch 24/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 0.0458 - val_loss: 0.0439 - learning_rate: 0.0010
# Epoch 25/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 0.0458 - val_loss: 0.0423 - learning_rate: 0.0010
# Epoch 26/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - loss: 0.0452 - val_loss: 0.0451 - learning_rate: 0.0010
# Epoch 27/150
# 618/621 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - loss: 0.0460
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 0.0459 - val_loss: 0.0500 - learning_rate: 0.0010
# Epoch 28/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step - loss: 0.0419 - val_loss: 0.0416 - learning_rate: 5.0000e-04
# Epoch 29/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 0.0416 - val_loss: 0.0410 - learning_rate: 5.0000e-04
# Epoch 30/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step - loss: 0.0417 - val_loss: 0.0400 - learning_rate: 5.0000e-04
# Epoch 31/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step - loss: 0.0420 - val_loss: 0.0399 - learning_rate: 5.0000e-04
# Epoch 32/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - loss: 0.0420 - val_loss: 0.0402 - learning_rate: 5.0000e-04
# Epoch 33/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 0.0418 - val_loss: 0.0405 - learning_rate: 5.0000e-04
# Epoch 34/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 0.0421 - val_loss: 0.0423 - learning_rate: 5.0000e-04
# Epoch 35/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 0.0416 - val_loss: 0.0390 - learning_rate: 5.0000e-04
# Epoch 36/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 0.0415 - val_loss: 0.0422 - learning_rate: 5.0000e-04
# Epoch 37/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 0.0417 - val_loss: 0.0409 - learning_rate: 5.0000e-04
# Epoch 38/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step - loss: 0.0416 - val_loss: 0.0408 - learning_rate: 5.0000e-04
# Epoch 39/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 432us/step - loss: 0.0414 - val_loss: 0.0401 - learning_rate: 5.0000e-04
# Epoch 40/150
# 606/621 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 0.0424
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 0.0415 - val_loss: 0.0390 - learning_rate: 5.0000e-04
# Epoch 41/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - loss: 0.0398 - val_loss: 0.0392 - learning_rate: 2.5000e-04
# Epoch 42/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 0.0399 - val_loss: 0.0383 - learning_rate: 2.5000e-04
# Epoch 43/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 0.0398 - val_loss: 0.0387 - learning_rate: 2.5000e-04
# Epoch 44/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 0.0399 - val_loss: 0.0386 - learning_rate: 2.5000e-04
# Epoch 45/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 0.0398 - val_loss: 0.0393 - learning_rate: 2.5000e-04
# Epoch 46/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 0.0398 - val_loss: 0.0380 - learning_rate: 2.5000e-04
# Epoch 47/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - loss: 0.0397 - val_loss: 0.0388 - learning_rate: 2.5000e-04
# Epoch 48/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 0.0398 - val_loss: 0.0395 - learning_rate: 2.5000e-04
# Epoch 49/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 0.0397 - val_loss: 0.0390 - learning_rate: 2.5000e-04
# Epoch 50/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 0.0397 - val_loss: 0.0381 - learning_rate: 2.5000e-04
# Epoch 51/150
# 611/621 ━━━━━━━━━━━━━━━━━━━━ 0s 329us/step - loss: 0.0404
# Epoch 51: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 0.0397 - val_loss: 0.0382 - learning_rate: 2.5000e-04
# Epoch 52/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step - loss: 0.0389 - val_loss: 0.0376 - learning_rate: 1.2500e-04
# Epoch 53/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 0.0389 - val_loss: 0.0379 - learning_rate: 1.2500e-04
# Epoch 54/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 0.0389 - val_loss: 0.0380 - learning_rate: 1.2500e-04
# Epoch 55/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 0.0389 - val_loss: 0.0378 - learning_rate: 1.2500e-04
# Epoch 56/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 434us/step - loss: 0.0389 - val_loss: 0.0376 - learning_rate: 1.2500e-04
# Epoch 57/150
# 465/621 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - loss: 0.0399
# Epoch 57: ReduceLROnPlateau reducing learning rate to 0.0001.
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 0.0389 - val_loss: 0.0378 - learning_rate: 1.2500e-04
# Epoch 58/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step - loss: 0.0388 - val_loss: 0.0376 - learning_rate: 1.0000e-04
# Epoch 59/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step - loss: 0.0388 - val_loss: 0.0374 - learning_rate: 1.0000e-04
# Epoch 60/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 0.0388 - val_loss: 0.0374 - learning_rate: 1.0000e-04
# Epoch 61/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 0.0388 - val_loss: 0.0375 - learning_rate: 1.0000e-04
# Epoch 62/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 0.0387 - val_loss: 0.0376 - learning_rate: 1.0000e-04
# Epoch 63/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - loss: 0.0387 - val_loss: 0.0374 - learning_rate: 1.0000e-04
# Epoch 64/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 0.0387 - val_loss: 0.0374 - learning_rate: 1.0000e-04
# Epoch 65/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step - loss: 0.0387 - val_loss: 0.0373 - learning_rate: 1.0000e-04
# Epoch 66/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 0.0387 - val_loss: 0.0374 - learning_rate: 1.0000e-04
# Epoch 67/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 0.0387 - val_loss: 0.0374 - learning_rate: 1.0000e-04
# Epoch 68/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 0.0387 - val_loss: 0.0375 - learning_rate: 1.0000e-04
# Epoch 69/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step - loss: 0.0386 - val_loss: 0.0373 - learning_rate: 1.0000e-04
# Epoch 70/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 0.0386 - val_loss: 0.0374 - learning_rate: 1.0000e-04
# Epoch 71/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 0.0386 - val_loss: 0.0374 - learning_rate: 1.0000e-04
# Epoch 72/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 438us/step - loss: 0.0386 - val_loss: 0.0372 - learning_rate: 1.0000e-04
# Epoch 73/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 0.0386 - val_loss: 0.0376 - learning_rate: 1.0000e-04
# Epoch 74/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - loss: 0.0386 - val_loss: 0.0372 - learning_rate: 1.0000e-04
# Epoch 75/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 0.0386 - val_loss: 0.0373 - learning_rate: 1.0000e-04
# Epoch 76/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 0.0386 - val_loss: 0.0374 - learning_rate: 1.0000e-04
# Epoch 77/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 0.0385 - val_loss: 0.0375 - learning_rate: 1.0000e-04
# Epoch 78/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 0.0385 - val_loss: 0.0372 - learning_rate: 1.0000e-04
# Epoch 79/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 0.0385 - val_loss: 0.0374 - learning_rate: 1.0000e-04
# Epoch 80/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 0.0385 - val_loss: 0.0374 - learning_rate: 1.0000e-04
# Epoch 81/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 0.0385 - val_loss: 0.0377 - learning_rate: 1.0000e-04
# Epoch 82/150
# 621/621 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 0.0385 - val_loss: 0.0373 - learning_rate: 1.0000e-04
# Epoch 82: early stopping
# Restoring model weights from the end of the best epoch: 72.
# Best val_loss : 0.037216

# %%
plt.figure(figsize=(10, 3))
plt.plot(history.history['loss'],     label='train', color='steelblue')
plt.plot(history.history['val_loss'], label='val',   color='orange', linestyle='--')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.title('Training Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Threshold per User per Kategori
#
# Fit pada **threshold data** (Bulan 5 — normal). Threshold = persentil 95 MAE per `(id_user, kategori_detail)`.

# %%
autoencoder = tf.keras.models.load_model(    f'{MODEL_DIR}/autoencoder.keras', compile=False)
X_thr     = df_threshold[SCALED_COLS].values.astype(np.float32)
X_thr_rec = autoencoder.predict(X_thr, verbose=0)
mae_thr = np.abs(X_thr - X_thr_rec).mean(axis=1)
df_threshold = df_threshold.copy()
df_threshold['mae'] = mae_thr
threshold_user_kat = (    df_threshold.groupby(['id_user', 'kategori_detail'])['mae']    .quantile(0.90)    .rename('threshold')    .reset_index())
threshold_kat = (    df_threshold.groupby('kategori_detail')['mae']    .quantile(0.90)    .rename('threshold')    .to_dict())
print(f"User×kategori combinations : {len(threshold_user_kat)}")
print(f"Kategori fallback          : {len(threshold_kat)}")
print(threshold_user_kat.head(10).to_string(index=False))
# Out:
# User×kategori combinations : 4013
# Kategori fallback          : 10
# id_user             kategori_detail    threshold
# USR-001           F&B dan Nongkrong 1.209244e-02
# USR-001 Groceries & Kebutuhan Pokok 2.962856e-02
# USR-001         Hiburan & Langganan 8.695142e-02
# USR-001       Investasi & Finansial 3.045150e+13
# USR-001  Kesehatan & Perawatan Diri 2.165450e-02
# USR-001                Transfer P2P 3.275015e-02
# USR-001                Transportasi 2.860445e-02
# USR-002    Belanja Online & Fashion 1.321660e-01
# USR-002           F&B dan Nongkrong 1.623177e-02
# USR-002 Groceries & Kebutuhan Pokok 1.291016e-02

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].hist(mae_thr, bins=50, color='steelblue', alpha=0.8)
axes[0].set_title('Distribusi MAE (threshold data)')
axes[0].set_xlabel('MAE')

axes[1].hist(threshold_user_kat['threshold'], bins=40, color='orange', alpha=0.8)
axes[1].set_title('Distribusi Threshold per User×Kategori')
axes[1].set_xlabel('Threshold (p90 MAE)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Validasi pada Test Data
#
# Evaluasi model pada fase test menggunakan kondisi dua syarat:
# prediksi anomali hanya aktif jika **MAE > threshold** sekaligus **nominal > mean_nominal** user di kategori tersebut (baseline dari threshold data).

# %%
df_test_val = pd.read_csv(f'{DATA_DIR}/pre_test.csv', parse_dates=['timestamp'])
X_test_val  = df_test_val[SCALED_COLS].values.astype(np.float32)
X_test_rec  = autoencoder.predict(X_test_val, verbose=0)
mae_test    = np.abs(X_test_val - X_test_rec).mean(axis=1)
df_test_val['mae'] = mae_test
threshold_dict = {    (row['id_user'], row['kategori_detail']): row['threshold']    for _, row in threshold_user_kat.iterrows()}
_median_thr = float(np.median(list(threshold_dict.values())))
df_test_val['threshold'] = df_test_val.apply(    lambda r: threshold_dict.get(        (r['id_user'], r['kategori_detail']),        threshold_kat.get(r['kategori_detail'], _median_thr)    ), axis=1)
user_cat_mean_nominal = (    df_threshold.groupby(['id_user', 'kategori_detail'])['nominal']    .mean()    .rename('mean_nominal')    .reset_index())
cat_mean_nominal = (    df_threshold.groupby('kategori_detail')['nominal']    .mean()    .to_dict())
df_test_val = df_test_val.merge(user_cat_mean_nominal, on=['id_user', 'kategori_detail'], how='left')
df_test_val['mean_nominal'] = df_test_val['mean_nominal'].fillna(    df_test_val['kategori_detail'].map(cat_mean_nominal))
df_test_val['pred_anomali'] = (    (df_test_val['mae'] > df_test_val['threshold']) &    (df_test_val['nominal'] > df_test_val['mean_nominal'])).astype(int)
y_true_val = df_test_val['label_anomali'].values.astype(int)
print(classification_report(y_true_val, df_test_val['pred_anomali'],                             target_names=['Normal', 'Anomali']))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.89      0.94     42986
#      Anomali       0.19      0.88      0.31      1329
#
#     accuracy                           0.89     44315
#    macro avg       0.59      0.88      0.63     44315
# weighted avg       0.97      0.89      0.92     44315

# %% [markdown]
# ## Simpan

# %%
threshold_dict = {    (row['id_user'], row['kategori_detail']): row['threshold']    for _, row in threshold_user_kat.iterrows()}
joblib.dump({    'threshold_user_kat' : threshold_dict,    'threshold_kat'      : threshold_kat,    'scaled_cols'        : SCALED_COLS,}, f'{MODEL_DIR}/model_meta.pkl')
print(f"autoencoder.keras  → {MODEL_DIR}")
print(f"model_meta.pkl     → {MODEL_DIR}")
# Out:
# autoencoder.keras  → ../../../model/03_ae
# model_meta.pkl     → ../../../model/03_ae
